# %%
import pandas as pd
#2010-01-01 ~ 2021-06 까지 누계자료
kto_data = pd.read_excel(
            "data/방한 외래관광객_20210824.xlsx"
            ,header = 1
            ,usecols = "A:P"
            ,skipfooter = 0
)

# %%
kto_data.head(50)
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3     인원수  증감률(%)     인원수.1  \
# 0        2010         01        아시아         중국   91252   -1.89   40425.0
# 1         NaN        NaN        NaN         일본  209184  -12.04  202825.0
# 2         NaN        NaN        NaN         대만   36399   -2.74   35788.0
# 3         NaN        NaN        NaN         홍콩   14545  -42.30   13874.0
# 4         NaN        NaN        NaN        마카오     554  -41.99     554.0
# 5         NaN        NaN        NaN        필리핀   21214   -2.79    3984.0
# 6         NaN        NaN        NaN      인도네시아    5061  -12.71    1840.0
# 7         NaN        NaN        NaN         태국   17814   27.73   13374.0
# 8         NaN        NaN        NaN        베트남    4515  -11.44    1384.0
# 9         NaN        NaN        NaN         인도    6026    9.13    1646.0
# 10        NaN        NaN        NaN      말레이시아    4559  -32.10    3292.0
# 11        NaN        NaN        NaN       싱가포르    5368  -16.36    4201.0
# ...
